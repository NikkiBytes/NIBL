# %%
import numpy 
import os
import pdb
import glob
import pandas as pd

# %%
logpath = "/Users/nikkibytes/Documents/bbx_logs_all/logs"

# %%
os.chdir(logpath)

# %%
for file in glob.glob("bbx*.log"):
   # print(file)
    sub= "sub-"+file.split("_")[1]
    session = "ses-"+file.split("_")[3]
    run = "run-"+file.split("_")[2].split("n")[1]

    #print(sub, session, run)
    try:
        df = pd.read_csv(file, engine="python", sep="\\t", header=None)
        df.columns = ["onset", "data", "keypress"]
        df = df[["onset", "data"]]
    except pd.errors.EmptyDataError:
        print("EMPTY FILE ", file)
    
    start = df[df["data"].str.contains("start key press")]
    tasty = df[df["data"].str.contains("image=SL.jpg|image=CO.jpg")]
    ntasty = df[df["data"].str.contains("image=USL.jpg|image=UCO.jpg")]
    water = df[df["data"].str.contains("image=water.jpg")]
    NN = df[df["data"].str.contains("Level injecting via pump at address 0")]
    TT = df[df["data"].str.contains("Level injecting via pump at address 1")]
    UU = df[df["data"].str.contains("Level injecting via pump at address 2")]
    rinse = df[df["data"].str.contains("Level RINSE")]

    start = start[["onset"]]
    start_time = float(start.iat[0,0])
    
    tasty = tasty[["onset"]]
    ntasty = ntasty[["onset"]]
    water = water[["onset"]]
    NN = NN[["onset"]]
    TT = TT[["onset"]]
    UU = UU[["onset"]]
    rinse = rinse[["onset"]]

    
    tasty = tasty["onset"] - start_time
    ntasty = ntasty["onset"] - start_time
    water = water["onset"] - start_time
    NN = NN["onset"] - start_time
    
    TT = TT["onset"] - start_time 
  
    UU = UU["onset"] - start_time
    
    rinse = rinse["onset"] - start_time
    

    outpath = "/Users/nikkibytes/Documents/bbx_logs_all/parsedlogs/"
    
    files2make=['rinse', 'TT', 'UU', 'NN', 'Tcue', 'Ucue', 'Ncue']
    
    for name in files2make:
        filename = "%s_%s_%s_%s.txt"%(sub, session, name, run)
        if name == "rinse":
            rinse.to_csv(outpath+filename, header=None, index=None)
        elif name == "TT":
            TT.to_csv(outpath+filename, header=None, index=None)
        elif name == "UU":
            UU.to_csv(outpath+filename, header=None, index=None)
        elif name == "NN":
            NN.to_csv(outpath+filename, header=None, index=None)
        elif name == "Tcue":
            tasty.to_csv(outpath+filename, header=None, index=None)
        elif name == "Ucue":
            ntasty.to_csv(outpath+filename, header=None, index=None)
        else:
            water.to_csv(outpath+filename, header=None, index=None)
            
        
#print(tasty.head())
#tasty.to_csv(outpath+"/test_text.txt",header=None, index=None)
# Out:
# sub-007 ses-pre run-04
# sub-006 ses-post run-04
# sub-022 ses-pre run-02
# sub-010 ses-pre run-02
# sub-022 ses-pre run-01
# sub-017 ses-post run-04
# sub-021 ses-2018-07-02-09 run-01
# sub-023 ses-post run-04
# sub-004 ses-post run-04
# sub-022 ses-post run-04
# sub-005 ses-pre run-02
# sub-007 ses-post run-02
# sub-012 ses-pre run-02
# sub-011 ses-post run-04
# sub-002 ses-2018-04-23-18 run-01
# sub-016 ses-pre run-03
# sub-008 ses-post run-02
# sub-003 ses-pre run-04
# sub-005 ses-2018-05-01-11 run-02
# sub-024 ses-pre run-04
# sub-021 ses-post run-03
# sub-015 ses-pre run-04
# sub-009 ses-post run-04
# sub-032 ses-pre run-01
# sub-019 ses-post run-03
# sub-013 ses-post run-03
# sub-011 ses-pre run-04
# sub-009 ses-post run-02
# sub-002 ses-pre run-03
# sub-005 ses-post run-01
# sub-024 ses-pre run-01
# sub-014 ses-pre run-04
# sub-017 ses-post run-03
# sub-021 ses-post run-02
# sub-022 ses-2018-07-18-20 run-02
# sub-003 ses-pre run-02
# sub-010 ses-2018-05-17-21 run-02
# sub-022 ses-post run-01
# sub-011 ses-2018-05-09-11 run-01
# sub-016 ses-post run-03
# sub-002 ses-pre run-01
# EMPTY FILE  bbx_002_run01_pre_2018-03-26-13_54_29_subdata.log
# sub-012 ses-pre run-01
# sub-004 ses-2018-05-02-11 run-01
# sub-013 ses-2018-06-06-20 run-02
# sub-020 ses-pre run-04
# sub-019 ses-pre run-01
# sub-002 ses-post run-03
# sub-023 ses-2018-07-11-09 run-01
# sub-008 ses-post run-01
# sub-015 ses-2018-06-13-09 run-01
# sub-016 ses-2018-06-21-20 run-01
# sub-013 ses-pre run-02
# sub-002 ses-post run-01
# sub-022 ses-pre run-04
# sub-001 ses-pre run-01
# EMPTY FILE  bbx_001_run01_pre_2018-03-23-12_37_34_subdata.log
# sub-007 ses-pre run-03
# sub-032 ses-pre run-03
# sub-016 ses-pre run-02
# sub-004 ses-pre run-02
# sub-023 ses-pre run-03
# sub-023 ses-pre run-01
# sub-010 ses-post run-03
# sub-009 ses-2018-05-04-09 run-02
# sub-012 ses-pre run-03
# sub-017 ses-pre run-03
# sub-007 ses-pre run-02
# sub-013 ses-post run-02
# sub-001 ses-post run-01
# sub-013 ses-pre run-03
# sub-024 ses-pre run-03
# sub-016 ses-post run-01
# sub-019 ses-2018-07-05-20 run-02
# sub-014 ses-post run-01
# sub-015 ses-post run-01
# sub-007 ses-post run-04
# sub-004 ses-pre run-01
# sub-006 ses-pre run-01
# sub-006 ses-pre run-03
# sub-016 ses-pre run-01
# sub-003 ses-pre run-03
# sub-010 ses-2018-05-17-21 run-01
# sub-008 ses-post run-03
# sub-009 ses-pre run-02
# sub-006 ses-post run-02
# sub-033 ses-pre run-03
# sub-002 ses-2018-04-23-18 run-02
# sub-002 ses-2018-04-23-18 run-01
# sub-019 ses-2018-07-05-20 run-01
# sub-019 ses-pre run-03
# sub-008 ses-post run-04
# sub-019 ses-post run-04
# sub-011 ses-post run-02
# sub-006 ses-2018-05-08-13 run-02
# sub-016 ses-post run-04
# sub-016 ses-pre run-04
# sub-019 ses-pre run-02
# sub-007 ses-2018-05-02-12 run-02
# sub-013 ses-pre run-04
# sub-022 ses-pre run-03
# sub-013 ses-post run-01
# sub-017 ses-2018-07-10-09 run-02
# sub-010 ses-post run-01
# sub-016 ses-2018-06-21-20 run-02
# sub-010 ses-post run-04
# sub-004 ses-post run-01
# sub-007 ses-pre run-04
# sub-021 ses-pre run-04
# sub-005 ses-pre run-03
# sub-023 ses-post run-03
# sub-013 ses-2018-06-06-20 run-01
# sub-009 ses-post run-01
# sub-021 ses-post run-01
# sub-011 ses-pre run-02
# sub-010 ses-pre run-03
# sub-024 ses-pre run-02
# sub-023 ses-pre run-04
# sub-002 ses-post run-04
# sub-017 ses-post run-02
# sub-010 ses-post run-01
# sub-019 ses-post run-02
# sub-020 ses-pre run-02
# sub-013 ses-pre run-01
# sub-032 ses-pre run-02
# sub-017 ses-2018-07-10-09 run-01
# sub-017 ses-pre run-02
# sub-006 ses-pre run-02
# sub-006 ses-post run-03
# sub-021 ses-pre run-01
# sub-001 ses-pre run-01
# sub-004 ses-post run-02
# sub-014 ses-post run-02
# sub-023 ses-post run-02
# sub-007 ses-post run-03
# sub-014 ses-pre run-01
# sub-005 ses-post run-04
# sub-011 ses-2018-05-09-11 run-02
# sub-001 ses-2018-04-16-19 run-01
# sub-008 ses-2018-05-07-17 run-02
# sub-010 ses-post run-02
# sub-019 ses-pre run-04
# sub-021 ses-post run-04
# sub-001 ses-pre run-04
# sub-008 ses-pre run-04
# sub-005 ses-post run-03
# sub-033 ses-pre run-01
# sub-020 ses-pre run-01
# sub-005 ses-pre run-02
# sub-021 ses-pre run-02
# sub-019 ses-post run-01
# sub-009 ses-2018-05-04-09 run-01
# sub-002 ses-post run-02
# sub-032 ses-pre run-04
# sub-033 ses-pre run-02
# sub-022 ses-post run-02
# sub-005 ses-pre run-01
# sub-003 ses-pre run-01
# sub-020 ses-pre run-03
# sub-006 ses-pre run-04
# sub-033 ses-pre run-04
# sub-019 ses-post run-04
# sub-011 ses-pre run-01
# sub-012 ses-pre run-04
# sub-021 ses-pre run-03
# sub-010 ses-pre run-04
# sub-011 ses-post run-01
# sub-022 ses-2018-07-18-20 run-01
# sub-001 ses-post run-03
# sub-009 ses-pre run-03
# sub-004 ses-pre run-04
# sub-014 ses-post run-03
# sub-014 ses-2018-06-20-16 run-02
# sub-017 ses-pre run-01
# sub-013 ses-post run-04
# sub-002 ses-pre run-02
# sub-009 ses-pre run-01
# sub-014 ses-2018-06-20-16 run-01
# sub-008 ses-2018-05-07-16 run-01
# sub-004 ses-post run-03
# sub-022 ses-post run-03
# sub-014 ses-pre run-01
# sub-017 ses-pre run-04
# sub-005 ses-2018-05-01-11 run-01
# sub-011 ses-post run-03
# sub-005 ses-pre run-04
# sub-007 ses-2018-05-02-12 run-01
# sub-015 ses-pre run-03
# sub-007 ses-pre run-01
# sub-008 ses-pre run-03
# sub-001 ses-2018-04-16-19 run-02
# sub-015 ses-post run-03
# sub-006 ses-post run-01
# sub-001 ses-post run-02
# sub-007 ses-post run-01
# sub-010 ses-pre run-01
# sub-009 ses-pre run-04
# sub-006 ses-2018-05-08-12 run-01
# sub-017 ses-post run-01
# sub-016 ses-post run-02
# sub-008 ses-pre run-01
# sub-015 ses-pre run-02
# sub-009 ses-post run-03
# sub-015 ses-post run-04
# sub-014 ses-post run-04
# sub-002 ses-pre run-01
# sub-015 ses-pre run-01
# sub-011 ses-pre run-03
# sub-014 ses-pre run-03
# sub-014 ses-pre run-02
# sub-004 ses-2018-05-02-11 run-02
# sub-001 ses-pre run-03
# sub-008 ses-pre run-02
# sub-002 ses-pre run-01
# sub-023 ses-post run-01
# sub-015 ses-post run-02
# sub-001 ses-pre run-02
# sub-001 ses-post run-04
# sub-023 ses-pre run-02
