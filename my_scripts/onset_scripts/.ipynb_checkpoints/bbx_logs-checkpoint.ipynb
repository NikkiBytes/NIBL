# %%
import os 
import pandas as pd
import glob

# %%
def getDict(sub):
    logdict[sub]={
        'POST': [],
        'PRE': [],
        'MISC': []
    }

# %%
logdict={}
path = os.path.join("/Users/nikkibytes/Documents/BBx_logs", "*log")
for file in glob.glob(path):
    filename = file.split("/")[5]
    sub="sub-"+filename.split("_")[1]
    run="run-"+filename.split("_")[2].split("0")[1]
    identifier=filename.split("_")[3]
    #print(filename, sub, run, identifier)
    if sub not in logdict.keys():
        getDict(sub)
    if identifier  == "post":
        logdict[sub]["POST"].append(run)
    elif identifier == "pre":
        logdict[sub]["PRE"].append(run)
    else:
        logdict[sub]["MISC"].append(run)
        logdict[sub]["MISC"].append(identifier)
        
        
    
    try:
        df = pd.read_table(file,engine="python", sep="\\t", header=None)
        df.columns = ["a", "b", "c"]
    except pd.errors.EmptyDataError:
        print("EMPTY FILE: ", filename)
# Out:
# EMPTY FILE:  bbx_002_run01_pre_2018-03-26-13_54_29_subdata.log
# EMPTY FILE:  bbx_001_run01_pre_2018-03-23-12_37_34_subdata.log

# %%
pd.DataFrame(logdict).T
# Out:
#                                                       MISC  \
# sub-007       [run-2, 2018-05-02-12, run-1, 2018-05-02-12]
# sub-006       [run-2, 2018-05-08-13, run-1, 2018-05-08-12]
# sub-022                                                 []
# sub-010       [run-2, 2018-05-17-21, run-1, 2018-05-17-21]
# sub-017       [run-2, 2018-07-10-09, run-1, 2018-07-10-09]
# sub-021                             [run-1, 2018-07-02-09]
# sub-023                             [run-1, 2018-07-11-09]
# sub-004       [run-1, 2018-05-02-11, run-2, 2018-05-02-11]
# sub-005       [run-2, 2018-05-01-11, run-1, 2018-05-01-11]
# sub-012                                                 []
# sub-011       [run-1, 2018-05-09-11, run-2, 2018-05-09-11]
# sub-002  [run-1, 2018-04-23-18, run-2, 2018-04-23-18, r...
# sub-016       [run-1, 2018-06-21-20, run-2, 2018-06-21-20]
# sub-008       [run-2, 2018-05-07-17, run-1, 2018-05-07-16]
# sub-003                                                 []
# sub-024                                                 []
# sub-015                             [run-1, 2018-06-13-09]
# sub-032                                                 []
# sub-019       [run-2, 2018-07-05-20, run-1, 2018-07-05-20]
# sub-013       [run-2, 2018-06-06-20, run-1, 2018-06-06-20]
# sub-009       [run-2, 2018-05-04-09, run-1, 2018-05-04-09]
# sub-014       [run-2, 2018-06-20-16, run-1, 2018-06-20-16]
# sub-020                                                 []
# sub-001       [run-1, 2018-04-16-19, run-2, 2018-04-16-19]
# sub-033                                                 []
#
#                                         POST  \
# sub-007         [run-2, run-4, run-3, run-1]
# sub-006         [run-4, run-2, run-3, run-1]
# sub-022                                   []
# sub-010  [run-3, run-1, run-4, run-1, run-2]
# sub-017         [run-4, run-3, run-2, run-1]
# sub-021         [run-3, run-2, run-1, run-4]
# sub-023         [run-4, run-3, run-2, run-1]
# sub-004         [run-4, run-1, run-2, run-3]
# sub-005                [run-1, run-4, run-3]
# sub-012                                   []
# sub-011         [run-4, run-2, run-1, run-3]
# sub-002         [run-3, run-1, run-4, run-2]
# sub-016         [run-3, run-1, run-4, run-2]
# sub-008         [run-2, run-1, run-3, run-4]
# sub-003                                   []
# sub-024                                   []
# sub-015         [run-1, run-3, run-4, run-2]
# sub-032                                   []
# sub-019  [run-3, run-4, run-2, run-1, run-4]
# sub-013         [run-3, run-2, run-1, run-4]
# sub-009                [run-2, run-1, run-3]
# sub-014         [run-1, run-2, run-3, run-4]
# sub-020                                   []
# sub-001         [run-1, run-3, run-2, run-4]
# sub-033                                   []
#
#                                          PRE
# sub-007  [run-4, run-3, run-2, run-4, run-1]
# sub-006         [run-1, run-3, run-2, run-4]
# sub-022         [run-2, run-1, run-4, run-3]
# sub-010         [run-2, run-3, run-4, run-1]
# sub-017         [run-3, run-2, run-1, run-4]
# sub-021         [run-4, run-1, run-2, run-3]
# sub-023         [run-3, run-1, run-4, run-2]
# sub-004                [run-2, run-1, run-4]
# sub-005  [run-2, run-3, run-2, run-1, run-4]
# sub-012         [run-2, run-1, run-3, run-4]
# sub-011         [run-4, run-2, run-1, run-3]
# sub-002  [run-3, run-1, run-2, run-1, run-1]
# sub-016         [run-3, run-2, run-1, run-4]
# sub-008         [run-4, run-3, run-1, run-2]
# sub-003         [run-4, run-2, run-3, run-1]
# sub-024         [run-4, run-1, run-3, run-2]
# sub-015         [run-4, run-3, run-2, run-1]
# sub-032         [run-1, run-3, run-2, run-4]
# sub-019         [run-1, run-3, run-2, run-4]
# sub-013         [run-2, run-3, run-4, run-1]
# sub-009                       [run-2, run-1]
# sub-014  [run-4, run-1, run-1, run-3, run-2]
# sub-020         [run-4, run-2, run-1, run-3]
# sub-001  [run-1, run-1, run-4, run-3, run-2]
# sub-033         [run-3, run-1, run-2, run-4]
